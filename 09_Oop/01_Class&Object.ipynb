# %% [markdown]
# syntax to create an object.

# %%
# Objectname = classname()
l = list() # here the l is object name and list is class name

# %% [markdown]
# BluePrint Vs Real Toys

# %%
class RobotPet:
    
    def __init__(self,assigned_name,color):
        self.name = assigned_name
        self.color = color
        self.battery = 100

# %%
robot_bob = RobotPet('Bob','red')
robot_zack = RobotPet('Zack',"white")

# %%
print(robot_bob.color)
print(robot_zack.name)
# Out:
# red
# Zack

# %% [markdown]
# Creating an ATM machine using class and Object.

# %%
class Atm:
    
    #constructor is a special Function. it has a super power that for the execute inside the constuctor code you don't have to call it.
    def __init__(self):
        self.pin = ''
        self.balance = 0
        self.menu()
        
    def menu(self):
        user_input = input("""
                 Hi how can i help you!
                 1. Press 1 to create a pin.
                 2. Press 2 to change a pin.
                 3. Press 3 to check Balance.
                 4. Press 4 to withdrawl Balance.
                 Anything else to exit.
                 """)
        
        
        if user_input == '1':
            #create pin
            self.create_pin()
        elif user_input == '2':
            #Change pin
            pass
        elif user_input == '3':
            #Check Balance
            pass
        elif user_input == '4':
            # withdrawl Balance
            pass
        else:
            exit()
            
    def create_pin(self):
        user_pin = input('enter your Pin')
        self.pin == user_pin
        user_balance = int(input("enter your Balance"))
        self.balance == user_balance
        
        print('Pin Created Successfully')
        
        
    def change_pin(self):
        old_pin = input("Enter Old Pin")
        
        
        if old_pin == self.pin:
            #Let him change the pin
            new_pin = input("Enter new Pin")
            self.pin = new_pin
            print('Pin changed successfully!')
            self.menu()
        else:
            print('Nai kerne de sakhta re baba!')
            self.menu()

# %%
obj = Atm()
# Out:
# Pin Created Successfully
