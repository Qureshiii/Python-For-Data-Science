# %% [markdown]
# __Indexing__

# %%
l = [[[1,2],[3,4]],[[5,6],[7,8]]]

# %%
l[1][1][1]
# Out:
# 8

# %% [markdown]
# __Slicing__

# %%
l = [1,2,3,4,5,6]

# %%
l[0:3]
# Out:
# [1, 2, 3]

# %%
l[-3:]
# Out:
# [4, 5, 6]

# %%
l[0::2]
# Out:
# [1, 3, 5]

# %%
l[-5:-2:2]
# Out:
# [2, 4]

# %%
l[::-1]
# Out:
# [6, 5, 4, 3, 2, 1]
