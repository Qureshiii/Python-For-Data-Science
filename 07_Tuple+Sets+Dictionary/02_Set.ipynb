# %% [markdown]
# __Sets__

# %% [markdown]
# A set is an unordered collection of items. Every set is unique(no duplicates) and must be immutable(cannot be changed). However a set itself is mutable. we add or remove item from it. sets can also be used to perform mathematical operations like union intersection, Symmetric difference etc.

# %% [markdown]
# characteristics :
#
# . Unordered
# . Mutable
# . No Duplicates
# . Can't contains mutable datatypes

# %% [markdown]
# _Creating sets_ :

# %%
#Empty
s = set()
print(s)
print(type(s))

# 1D 
s1 = {1,2,3}
print(s1)

# you cannot have a mutable datatype inside a set. So thats why we cannot create 2D Sets.

#Hatero
s2 = {1,2.5,True,'hello',(1,2,3)}
s2
# Out:
# set()
# <class 'set'>
# {1, 2, 3}
# {(1, 2, 3), 1, 2.5, 'hello'}

# %%
s1 = {1,2,3,4,5}
s2 = {4,5,6,7,8}
print(s1 | s2) #Union (|)
print(s1 & s2) # Intersection (&)
print(s1 - s2) #Difference (-)
print((s1 ^ s2)) # Symmetric difference (^)

#Membership test
print(1 in s1)
print(5 not in s1)

# Iteration 
for i in s1:
    print(i)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}
# {4, 5}
# {1, 2, 3}
# {1, 2, 3, 6, 7, 8}
# True
# False
# 1
# 2
# 3
# 4
# 5
